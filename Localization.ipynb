# %%
# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

#=====[ Standard + Math ]=====
import os
import sys
sys.path.insert(0, './') #for faster development
import pickle
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %pylab inline

#=====[ ModalDB ]=====
from ModalDB import ModalClient
from ModalDB import Video
from ModalDB import Frame

#=====[ convcube ]=====
from convcube.schema import convcube_schema
from convcube.cs231n.data_utils import load_tiny_imagenet
from convcube.localization import load_dataset_localization
from convcube.localization import LocalizationConvNet
from convcube.cube import ConvNetCube

#=====[ setup client ]=====
client = ModalClient('./data/db', schema=convcube_schema)
models_path = './models/localization'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# #I. Pretraining on ImageNet
# Skip this section if you can load an already-pretrained model

# %% [markdown]
# ### Get Data

# %%
imagenet_path = './convcube/cs231n/datasets/tiny-imagenet-100-A'
class_names, X_train, y_train, X_val, y_val, X_test, y_test = load_tiny_imagenet(imagenet_path)
print 'Train data shape: ', X_train.shape
print 'Train labels shape: ', y_train.shape
print 'Validation data shape: ', X_val.shape
print 'Validation labels shape: ', y_val.shape
print 'Test data shape: ', X_test.shape
# Out:
# loading training data for synset 20 / 100
# loading training data for synset 40 / 100
# loading training data for synset 60 / 100
# loading training data for synset 80 / 100
# loading training data for synset 100 / 100
# Train data shape:
#  (50000, 3, 64, 64)
# Train labels shape:  (50000,)
# Validation data shape:  (5000, 3, 64, 64)
# Validation labels shape:  (5000,)
# Test data shape:  (5000, 3, 64, 64)

# %% [markdown]
# ### Get Model

# %%
#=====[ LOAD MODEL ]=====
#*****
model_path = os.path.join(models_path, 'pretrained/convnet_10s.pkl')
pretrained_model = pickle.load(open(model_path))
#*****

# %%
#=====[ TRAIN MODEL ]=====
#*****
convnet = LocalizationConvNet()
model = convnet.init_pretrain_convnet()
model, loss_hist, train_acc_hist, val_acc_hist = convnet.pretrain(X_train, y_train, X_val, y_val)
pretrained_model = model
model_path = os.path.join(models_path, 'pretrained/convnet_10.pkl')
pickle.dump(pretrained_model, open(model_path, 'w'))
#*****

# %% [markdown]
# #II. Transfer Learning on Rubiks Cubes

# %% [markdown]
# ### Get Data

# %%
X_train, X_val, y_train, y_val = load_dataset_localization(client, train_size=0.9)
print 'Train data shape: ', X_train.shape
print 'Train labels shape: ', y_train.shape
print 'Validation data shape: ', X_val.shape
print 'Validation labels shape: ', y_val.shape
# Out:
# Train data shape:  (711, 3, 90, 160)
# Train labels shape:  (711, 4)
# Validation data shape:  (80, 3, 90, 160)
# Validation labels shape:  (80, 4)

# %% [markdown]
# ### Get Model

# %%
#=====[ LOAD MODEL ]=====
#*****
convnet = LocalizationConvNet()
convnet.load('models/localization/10s.loc_convnet')
#*****

# %%
#=====[ TRAIN MODEL ]=====
#*****
convnet = LocalizationConvNet(pretrained_model=pretrained_model)
out = convnet.train(X_train, y_train, X_val, y_val)
model, loss_hist, train_acc_hist, val_acc_hist = out
convnet.save('models/localization/10s.loc_convnet_border')
#*****
# Out:
# starting iteration  0
# Finished epoch 0 / 15: cost 0.570295, train: 9.000461, val 8.877103, lr 2.000000e-04
# starting iteration
#  10
# Finished epoch 1 / 15: cost 0.476044, train: 0.902507, val 0.903803, lr 1.900000e-04
# starting iteration
#  20
# Finished epoch 2 / 15: cost 0.406535, train: 0.622541, val 0.618429, lr 1.805000e-04
# starting iteration
#  30
# starting iteration
#  40
# Finished epoch 3 / 15: cost 0.288311, train: 0.365965, val 0.355905, lr 1.714750e-04
# starting iteration
#  50
# Finished epoch 4 / 15: cost 0.224465, train: 0.210555, val 0.196552, lr 1.629012e-04
# starting iteration
#  60
# Finished epoch 5 / 15: cost 0.186392, train: 0.171999, val 0.162468, lr 1.547562e-04
# starting iteration  70
# starting iteration
#  80
# Finished epoch 6 / 15: cost 0.139818, train: 0.097116, val 0.087423, lr 1.470184e-04
# starting iteration
#  90
# Finished epoch 7 / 15: cost 0.116077, train: 0.070907, val 0.063842, lr 1.396675e-04
# starting iteration
#  100
# starting iteration
#  110
# Finished epoch 8 / 15: cost 0.093778, train: 0.053505, val 0.050782, lr 1.326841e-04
# starting iteration
#  120
# Finished epoch 9 / 15: cost 0.096452, train: 0.046427, val 0.043120, lr 1.260499e-04
# starting iteration
#  130
# Finished epoch 10 / 15: cost 0.085587, train: 0.041554, val 0.040171, lr 1.197474e-04
# starting iteration  140
# starting iteration
#  150
# Finished epoch 11 / 15: cost 0.089934, train: 0.037995, val 0.037031, lr 1.137600e-04
# starting iteration
#  160
# Finished epoch 12 / 15: cost 0.084430, train: 0.036880, val 0.035847, lr 1.080720e-04
# starting iteration
#  170
# starting iteration
#  180
# Finished epoch 13 / 15: cost 0.084142, train: 0.034375, val 0.035679, lr 1.026684e-04
# starting iteration
#  190
# Finished epoch 14 / 15: cost 0.079174, train: 0.033348, val 0.034835, lr 9.753500e-05
# starting iteration
#  200
# Finished epoch 15 / 15: cost 0.092424, train: 0.032076, val 0.034975, lr 9.265825e-05
# finished optimization. best validation accuracy: 0.034835

# %% [markdown]
# ### Visualize Loss

# %%
plt.plot(train_acc_hist[5:])
plt.plot(val_acc_hist[5:])
plt.xlabel('Training Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss During Training')

# %% [markdown]
# ### Visualize Cost

# %%
plt.plot(loss_hist[20:])
plt.xlabel('Training Epoch')
plt.ylabel('Loss')
plt.title('loss hist over training')

# %% [markdown]
# #III. Visualizing Results

# %%
from convcube import ConvNetCube
from convcube.utils.wrangling import iter_unlabeled_frames
from convcube.utils.wrangling import iter_labeled_frames
from convcube.localization.utils import get_y_localization
from convcube.localization.utils import get_X_localization
from convcube.utils.drawing import draw_points
cube = ConvNetCube(loc_convnet=convnet)

# %% [markdown]
# ### Draw on Random Frame

# %%
frame = client.get_random(Frame)
image = frame['image'].copy()
disp_img = cube.draw_output(image)
plt.imshow(disp_img[:,:,::-1])
