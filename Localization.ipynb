# %%
# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

#=====[ Standard + Math ]=====
import os
import sys
sys.path.insert(0, './') #for faster development
import pickle
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %pylab inline

#=====[ ModalDB ]=====
from ModalDB import ModalClient
from ModalDB import Video
from ModalDB import Frame

#=====[ convcube ]=====
from convcube.schema import convcube_schema
from convcube.cs231n.data_utils import load_tiny_imagenet
from convcube.localization import load_dataset_localization
from convcube.localization import LocalizationConvNet
from convcube.cube import ConvNetCube

#=====[ setup client ]=====
client = ModalClient('./data/db', schema=convcube_schema)
models_path = './models/localization'
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# #I. Pretraining on ImageNet
# Skip this section if you can load an already-pretrained model

# %% [markdown]
# ### Get Data

# %%
imagenet_path = './convcube/cs231n/datasets/tiny-imagenet-100-A'
class_names, X_train, y_train, X_val, y_val, X_test, y_test = load_tiny_imagenet(imagenet_path)
print 'Train data shape: ', X_train.shape
print 'Train labels shape: ', y_train.shape
print 'Validation data shape: ', X_val.shape
print 'Validation labels shape: ', y_val.shape
print 'Test data shape: ', X_test.shape
# Out:
# loading training data for synset 20 / 100
# loading training data for synset 40 / 100
# loading training data for synset 60 / 100
# loading training data for synset 80 / 100
# loading training data for synset 100 / 100
# Train data shape:
#  (50000, 3, 64, 64)
# Train labels shape:  (50000,)
# Validation data shape:  (5000, 3, 64, 64)
# Validation labels shape:  (5000,)
# Test data shape:  (5000, 3, 64, 64)

# %% [markdown]
# ### Get Model

# %%
#=====[ LOAD MODEL ]=====
#*****
model_path = os.path.join(models_path, 'pretrained/convnet_10s.pkl')
pretrained_model = pickle.load(open(model_path))
#*****

# %%
#=====[ TRAIN MODEL ]=====
#*****
convnet = LocalizationConvNet()
model = convnet.init_pretrain_convnet()
model, loss_hist, train_acc_hist, val_acc_hist = convnet.pretrain(X_train, y_train, X_val, y_val)
pretrained_model = model
model_path = os.path.join(models_path, 'pretrained/convnet_10.pkl')
pickle.dump(pretrained_model, open(model_path, 'w'))
#*****

# %% [markdown]
# #II. Transfer Learning on Rubiks Cubes

# %% [markdown]
# ### Get Data

# %%
X_train, X_val, y_train, y_val = load_dataset_localization(client, train_size=0.9)
print 'Train data shape: ', X_train.shape
print 'Train labels shape: ', y_train.shape
print 'Validation data shape: ', X_val.shape
print 'Validation labels shape: ', y_val.shape
# Out:
# Train data shape:  (711, 3, 46, 80)
# Train labels shape:  (711, 2)
# Validation data shape:  (80, 3, 46, 80)
# Validation labels shape:  (80, 2)

# %% [markdown]
# ### Get Model

# %%
#=====[ LOAD MODEL ]=====
#*****
convnet = LocalizationConvNet()
convnet.load('models/localization/10s.loc_convnet')
#*****

# %%
#=====[ TRAIN MODEL ]=====
#*****
convnet = LocalizationConvNet(pretrained_model=pretrained_model)
out = convnet.train(X_train, y_train, X_val, y_val)
model, loss_hist, train_acc_hist, val_acc_hist = out
convnet.save('models/localization/10s.loc_convnet')
#*****
# Out:
# starting iteration  0
# Finished epoch 0 / 80: cost 0.229145, train: 2.612401, val 2.465675, lr 5.000000e-05
# starting iteration
#  10
# Finished epoch 1 / 80: cost 0.108104, train: 0.064587, val 0.074055, lr 5.000000e-05
# starting iteration
#  20
# Finished epoch 2 / 80: cost 0.097729, train: 0.053240, val 0.062155, lr 5.000000e-05
# starting iteration
#  30
# starting iteration
#  40
# Finished epoch 3 / 80: cost 0.091694, train: 0.045502, val 0.053796, lr 5.000000e-05
# starting iteration
#  50
# Finished epoch 4 / 80: cost 0.084094, train: 0.039918, val 0.047578, lr 5.000000e-05
# starting iteration
#  60
# Finished epoch 5 / 80: cost 0.088031, train: 0.035608, val 0.043076, lr 5.000000e-05
# starting iteration  70
# starting iteration
#  80
# Finished epoch 6 / 80: cost 0.078244, train: 0.032062, val 0.039837, lr 5.000000e-05
# starting iteration
#  90
# Finished epoch 7 / 80: cost 0.074645, train: 0.028062, val 0.034524, lr 5.000000e-05
# starting iteration
#  100
# starting iteration
#  110
# Finished epoch 8 / 80: cost 0.059141, train: 0.024790, val 0.030692, lr 5.000000e-05
# starting iteration
#  120
# Finished epoch 9 / 80: cost 0.070344, train: 0.021907, val 0.028026, lr 5.000000e-05
# starting iteration
#  130
# Finished epoch 10 / 80: cost 0.049969, train: 0.020752, val 0.027306, lr 5.000000e-05
# starting iteration  140
# starting iteration
#  150
# Finished epoch 11 / 80: cost 0.043161, train: 0.018048, val 0.024615, lr 5.000000e-05
# starting iteration
#  160
# Finished epoch 12 / 80: cost 0.048541, train: 0.016372, val 0.021544, lr 5.000000e-05
# starting iteration
#  170
# starting iteration
#  180
# Finished epoch 13 / 80: cost 0.046832, train: 0.015711, val 0.022410, lr 5.000000e-05
# starting iteration
#  190
# Finished epoch 14 / 80: cost 0.042670, train: 0.013512, val 0.018971, lr 5.000000e-05
# starting iteration
#  200
# Finished epoch 15 / 80: cost 0.052188, train: 0.016117, val 0.020205, lr 5.000000e-05
# starting iteration  210
# starting iteration
#  220
# Finished epoch 16 / 80: cost 0.047307, train: 0.012069, val 0.018941, lr 5.000000e-05
# starting iteration
#  230
# Finished epoch 17 / 80: cost 0.043174, train: 0.011174, val 0.017068, lr 5.000000e-05
# starting iteration
#  240
# starting iteration
#  250
# Finished epoch 18 / 80: cost 0.045094, train: 0.011213, val 0.018121, lr 5.000000e-05
# starting iteration
#  260
# Finished epoch 19 / 80: cost 0.029438, train: 0.009449, val 0.016180, lr 5.000000e-05
# starting iteration
#  270
# Finished epoch 20 / 80: cost 0.042832, train: 0.009061, val 0.015863, lr 5.000000e-05
# starting iteration  280
# starting iteration
#  290
# Finished epoch 21 / 80: cost 0.042530, train: 0.010350, val 0.018408, lr 5.000000e-05
# starting iteration
#  300
# Finished epoch 22 / 80: cost 0.045791, train: 0.010269, val 0.017584, lr 5.000000e-05
# starting iteration
#  310
# starting iteration
#  320
# Finished epoch 23 / 80: cost 0.050490, train: 0.009845, val 0.017516, lr 5.000000e-05
# starting iteration
#  330
# Finished epoch 24 / 80: cost 0.043786, train: 0.009005, val 0.013743, lr 5.000000e-05
# starting iteration
#  340
# Finished epoch 25 / 80: cost 0.044649, train: 0.009590, val 0.014224, lr 5.000000e-05
# starting iteration  350
# starting iteration
#  360
# Finished epoch 26 / 80: cost 0.030313, train: 0.006340, val 0.012948, lr 5.000000e-05
# starting iteration
#  370
# Finished epoch 27 / 80: cost 0.059516, train: 0.017067, val 0.026394, lr 5.000000e-05
# starting iteration
#  380
# starting iteration
#  390
# Finished epoch 28 / 80: cost 0.031097, train: 0.005945, val 0.011762, lr 5.000000e-05
# starting iteration
#  400
# Finished epoch 29 / 80: cost 0.031912, train: 0.006426, val 0.012848, lr 5.000000e-05
# starting iteration
#  410
# Finished epoch 30 / 80: cost 0.060914, train: 0.021402, val 0.030088, lr 5.000000e-05
# starting iteration  420
# starting iteration
#  430
# Finished epoch 31 / 80: cost 0.030150, train: 0.004922, val 0.009865, lr 5.000000e-05
# starting iteration
#  440
# Finished epoch 32 / 80: cost 0.033280, train: 0.004870, val 0.010512, lr 5.000000e-05
# starting iteration
#  450
# starting iteration
#  460
# Finished epoch 33 / 80: cost 0.033397, train: 0.006235, val 0.012970, lr 5.000000e-05
# starting iteration
#  470
# Finished epoch 34 / 80: cost 0.045318, train: 0.013568, val 0.021643, lr 5.000000e-05
# starting iteration
#  480
# Finished epoch 35 / 80: cost 0.028650, train: 0.004883, val 0.009598, lr 5.000000e-05
# starting iteration  490
# starting iteration
#  500
# Finished epoch 36 / 80: cost 0.042445, train: 0.007788, val 0.014855, lr 5.000000e-05
# starting iteration
#  510
# Finished epoch 37 / 80: cost 0.046124, train: 0.007612, val 0.014106, lr 5.000000e-05
# starting iteration
#  520
# starting iteration
#  530
# Finished epoch 38 / 80: cost 0.032607, train: 0.004178, val 0.010168, lr 5.000000e-05
# starting iteration
#  540
# Finished epoch 39 / 80: cost 0.029342, train: 0.004906, val 0.011136, lr 5.000000e-05
# starting iteration
#  550
# Finished epoch 40 / 80: cost 0.031303, train: 0.005474, val 0.009830, lr 5.000000e-05
# starting iteration  560
# starting iteration
#  570
# Finished epoch 41 / 80: cost 0.025340, train: 0.004421, val 0.008790, lr 5.000000e-05
# starting iteration
#  580
# Finished epoch 42 / 80: cost 0.034162, train: 0.004661, val 0.009191, lr 5.000000e-05
# starting iteration
#  590
# starting iteration
#  600
# Finished epoch 43 / 80: cost 0.027750, train: 0.004095, val 0.008527, lr 5.000000e-05
# starting iteration
#  610
# Finished epoch 44 / 80: cost 0.031065, train: 0.005265, val 0.010957, lr 5.000000e-05
# starting iteration
#  620
# Finished epoch 45 / 80: cost 0.028293, train: 0.004184, val 0.010068, lr 5.000000e-05
# starting iteration  630
# starting iteration
#  640
# Finished epoch 46 / 80: cost 0.030455, train: 0.005236, val 0.011092, lr 5.000000e-05
# starting iteration
#  650
# Finished epoch 47 / 80: cost 0.030695, train: 0.005343, val 0.011252, lr 5.000000e-05
# starting iteration
#  660
# starting iteration
#  670
# Finished epoch 48 / 80: cost 0.023224, train: 0.003036, val 0.007827, lr 5.000000e-05
# starting iteration
#  680
# Finished epoch 49 / 80: cost 0.034106, train: 0.007620, val 0.013668, lr 5.000000e-05
# starting iteration
#  690
# Finished epoch 50 / 80: cost 0.031063, train: 0.005749, val 0.010924, lr 5.000000e-05
# starting iteration  700
# starting iteration
#  710
# Finished epoch 51 / 80: cost 0.020811, train: 0.002904, val 0.007658, lr 5.000000e-05
# starting iteration
#  720
# Finished epoch 52 / 80: cost 0.058373, train: 0.013432, val 0.015994, lr 5.000000e-05
# starting iteration
#  730
# starting iteration
#  740
# Finished epoch 53 / 80: cost 0.031957, train: 0.004783, val 0.008098, lr 5.000000e-05
# starting iteration
#  750
# Finished epoch 54 / 80: cost 0.031511, train: 0.006431, val 0.009728, lr 5.000000e-05
# starting iteration
#  760
# Finished epoch 55 / 80: cost 0.044677, train: 0.005921, val 0.008844, lr 5.000000e-05
# starting iteration  770
# starting iteration
#  780
# Finished epoch 56 / 80: cost 0.024490, train: 0.003070, val 0.007911, lr 5.000000e-05
# starting iteration
#  790
# Finished epoch 57 / 80: cost 0.029638, train: 0.004134, val 0.007439, lr 5.000000e-05
# starting iteration
#  800
# starting iteration
#  810
# Finished epoch 58 / 80: cost 0.043131, train: 0.008006, val 0.011706, lr 5.000000e-05
# starting iteration
#  820
# Finished epoch 59 / 80: cost 0.051212, train: 0.011378, val 0.016221, lr 5.000000e-05
# starting iteration
#  830
# Finished epoch 60 / 80: cost 0.031256, train: 0.004170, val 0.007183, lr 5.000000e-05
# starting iteration  840
# starting iteration
#  850
# Finished epoch 61 / 80: cost 0.017931, train: 0.002404, val 0.006410, lr 5.000000e-05
# starting iteration
#  860
# Finished epoch 62 / 80: cost 0.045344, train: 0.008627, val 0.010911, lr 5.000000e-05
# starting iteration
#  870
# starting iteration
#  880
# Finished epoch 63 / 80: cost 0.027579, train: 0.003541, val 0.007138, lr 5.000000e-05
# starting iteration
#  890
# Finished epoch 64 / 80: cost 0.023098, train: 0.002790, val 0.006535, lr 5.000000e-05
# starting iteration
#  900
# Finished epoch 65 / 80: cost 0.022938, train: 0.003999, val 0.008287, lr 5.000000e-05
# starting iteration  910
# starting iteration
#  920
# Finished epoch 66 / 80: cost 0.017559, train: 0.002993, val 0.007582, lr 5.000000e-05
# starting iteration
#  930
# Finished epoch 67 / 80: cost 0.067996, train: 0.014043, val 0.016144, lr 5.000000e-05
# starting iteration
#  940
# starting iteration
#  950
# Finished epoch 68 / 80: cost 0.018795, train: 0.002285, val 0.006264, lr 5.000000e-05
# starting iteration
#  960
# Finished epoch 69 / 80: cost 0.036318, train: 0.004935, val 0.008047, lr 5.000000e-05
# starting iteration
#  970
# Finished epoch 70 / 80: cost 0.029346, train: 0.004496, val 0.008247, lr 5.000000e-05
# starting iteration  980
# starting iteration
#  990
# Finished epoch 71 / 80: cost 0.022939, train: 0.003337, val 0.006651, lr 5.000000e-05
# starting iteration
#  1000
# Finished epoch 72 / 80: cost 0.020810, train: 0.002164, val 0.005980, lr 5.000000e-05
# starting iteration
#  1010
# starting iteration
#  1020
# Finished epoch 73 / 80: cost 0.039864, train: 0.007883, val 0.013427, lr 5.000000e-05
# starting iteration
#  1030
# Finished epoch 74 / 80: cost 0.030394, train: 0.005203, val 0.010572, lr 5.000000e-05
# starting iteration
#  1040
# Finished epoch 75 / 80: cost 0.015871, train: 0.001931, val 0.006108, lr 5.000000e-05
# starting iteration  1050
# starting iteration
#  1060
# Finished epoch 76 / 80: cost 0.016163, train: 0.002024, val 0.005829, lr 5.000000e-05
# starting iteration
#  1070
# Finished epoch 77 / 80: cost 0.022869, train: 0.003112, val 0.007980, lr 5.000000e-05
# starting iteration
#  1080
# starting iteration
#  1090
# Finished epoch 78 / 80: cost 0.026144, train: 0.003699, val 0.008690, lr 5.000000e-05
# starting iteration
#  1100
# Finished epoch 79 / 80: cost 0.021332, train: 0.002628, val 0.006452, lr 5.000000e-05
# starting iteration
#  1110
# Finished epoch 80 / 80: cost 0.014130, train: 0.001766, val 0.005840, lr 5.000000e-05
# finished optimization. best validation accuracy: 0.005829

# %% [markdown]
# ### Visualize Loss

# %%
plt.plot(train_acc_hist[5:])
plt.plot(val_acc_hist[5:])
plt.xlabel('Training Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss During Training')

# %% [markdown]
# ### Visualize Cost

# %%
plt.plot(loss_hist[20:])
plt.xlabel('Training Epoch')
plt.ylabel('Loss')
plt.title('loss hist over training')

# %% [markdown]
# #III. Visualizing Results

# %%
from convcube import ConvNetCube
from convcube.utils.wrangling import iter_unlabeled_frames
from convcube.utils.wrangling import iter_labeled_frames
from convcube.localization.utils import get_y_localization
from convcube.localization.utils import get_X_localization
from convcube.utils.drawing import draw_points
cube = ConvNetCube(loc_convnet=convnet)

# %% [markdown]
# ### Draw on Random Frame

# %%
frame = client.get_random(Frame)
image = frame['image'].copy()
disp_img = cube.draw_output(image)
plt.imshow(disp_img[:,:,::-1])

# %%
convnet = LocalizationConvNet()
scores = convnet.localization_convnet(X_val, model)



for frame in iter_labeled_frames(client):

    image = frame['image'].copy()
    kpts = frame['interior_points']
    X = get_X_localization(frame['image'])
    y = get_y_localization(frame['interior_points'])
    y_pred = convnet.localization_convnet(X, model)[0]

    
    y_pred[0] = y_pred[0] * 640
    y_pred[1] = y_pred[1] * 360

    y[0] = y[0] * 640
    y[1] = y[1] * 360
    print y, y_pred

    disp_img = image.copy()
    cv2.circle(disp_img, (int(y[0]), int(y[1])), 5, color=(0, 255, 0), thickness=2)
    cv2.circle(disp_img, (int(y_pred[0]), int(y_pred[1])), 5, color=(0, 0, 255), thickness=2)
    plt.imshow(disp_img[:,:,::-1])

    break
    #     print frame['interior_points']
#     X = get_X_localization(frame['image'])
#     loss, grads = conv.localization_convnet(X, model, y=y)
#     print loss, grads
# Out:
# [ 398.5  180. ] [ 352.21118164  198.81999207]
