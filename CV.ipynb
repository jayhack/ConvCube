# %%
# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

#=====[ Standard + Math ]=====
import os
import sys
sys.path.insert(0, './') #for faster development
import pickle
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %pylab inline

#=====[ ModalDB ]=====
from ModalDB import ModalClient
from ModalDB import Video
from ModalDB import Frame

#=====[ convcube ]=====
from convcube.db import dbschema
from convcube.convnets.pinpointing import load_dataset_pinpointing
from convcube.cv.keypoints import *
from convcube.cv.preprocess import *

#=====[ setup client ]=====
client = ModalClient('./data/db', schema=dbschema)
models_path = './models/'
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Load Data

# %%
X_train, X_val, y_train, y_val = load_dataset_pinpointing(client, name='all', train_size=0.9)
print 'Train data shape: ', X_train.shape
print 'Train labels shape: ', y_train.shape
print 'Validation data shape: ', X_val.shape
print 'Validation labels shape: ', y_val.shape
# Out:
# Train data shape:  (1252, 3, 64, 64)
# Train labels shape:  (1252, 24)
# Validation data shape:  (140, 3, 64, 64)
# Validation labels shape:  (140, 24)

# %%
ix_train = (y_train[:,0] >= 0.0)
ix_val = (y_val[:,0] >= 0.0)
X_train_wy, X_val_wy = X_train[ix_train, :, :, :], X_val[ix_val, :, :, :]
y_train_wy, y_val_wy = y_train[ix_train, :8], y_val[ix_val, :8]

# %% [markdown]
# ## Gather Images, Intersesting Points

# %%
from convcube.cv.keypoints import interesting_points
from convcube.cv.keypoints import array2tuples
images = []
ipoints = []
corners = []
num_images = X_train_wy.shape[0]
for i in range(num_images):
    image = X_train_wy[i,:,:,:].transpose(1, 2, 0).copy()
    images.append(image)
    ipoints.append(interesting_points(image))
    corners.append(array2tuples(y_train_wy[i,:].reshape(4,2)))

# %% [markdown]
# ## Get Close Interesting Points

# %%
ix = 0

# %%
from convcube.cv.keypoints import normalize_points

def get_close_points(corners, ips):
    """assumes both are normalized to 0,1"""
    ips = tuples2array(ips)
    pos, neg = [], []
    near_ix = np.zeros(ips.shape[0])
    far_ix = np.ones(ips.shape[0])
    for c in corners:
        c = np.array(c)
        dists = np.sqrt(np.sum((ips - c)**2, axis=1))
        near_ix[dists < 0.05] += 1
        far_ix[dists < 0.1] = 0
    near_ix = near_ix >= 1
    far_ix = far_ix > 0
    pos = array2tuples(ips[near_ix, :])
    neg = array2tuples(ips[far_ix, :])
    return pos, neg


img = images[ix].copy()
crns = corners[ix]
ips = interesting_points(img)
ips = normalize_points(ips, image)
pos, neg = get_close_points(crns, ips)
for pt in crns:
    x = int(pt[0] * 64.0)
    y = int(pt[1] * 64.0)
    img[y-1:y+1, x-1:x+1, :]  = (0, 255, 0)

for pt in pos:
    x = int(pt[0]*64.0)
    y = int(pt[1]*64.0)
    img[y-1:y+1, x-1:x+1, :]  = (255, 0, 0)
    
for pt in neg:
    x = int(pt[0] * 64.0)
    y = int(pt[1] * 64.0)
    img[y-1:y+1, x-1:x+1, :]  = (0, 0, 255)
    

plt.imshow(img[:,:,::-1])
ix += 1

# %%
from convcube.cv.keypoints import tuples2array, array2tuples
from convcube.cv.keypoints import normalize_points
from convcube.cv.keypoints import tuples2kpts
X, y = [], []
sift = cv2.SIFT(400)
for img, c, ip in zip(images, corners, ipoints):

    ip = normalize_points(ip, img)
    pos, neg = get_close_points(c, ip)
    pos, neg = tuples2kpts(pos, size=3), tuples2kpts(neg, size=3)
    
#     pos_X_1 = sift.compute(img[:,:,0], pos, None)[1]
#     pos_X_2 = sift.compute(img[:,:,1], pos, None)[1]
#     pos_X_3 = sift.compute(img[:,:,2], pos, None)[1]
#     pos_X = np.hstack([pos_X_1, pos_X_2, pos_X_3])
    pos_X = sift.compute(img, pos, None)[1]
#     neg_X_1 = sift.compute(img[:,:,0], neg, None)[1]
#     neg_X_2 = sift.compute(img[:,:,1], neg, None)[1]
#     neg_X_3 = sift.compute(img[:,:,2], neg, None)[1]
#     neg_X = np.hstack([neg_X_1, neg_X_2, neg_X_3])
    neg_X = sift.compute(img, neg, None)[1]

    
    if not pos_X is None:
        X.append(pos_X)
        y.append(np.ones(pos_X.shape[0]))
    if not neg_X is None:
        X.append(neg_X)
        y.append(np.zeros(neg_X.shape[0]))


X = [x for x in X if len(x.shape) == 2 and x.shape[1] == 128]
X = np.vstack(X)
y = np.concatenate(y)
print y.sum()
# Out:
# 2297.0

# %%
random_ix = np.random.randn(X.shape[0]) > -1.5
X_train, y_train = X[random_ix, :], y[random_ix]
X_val, y_val= X[~random_ix,:], y[~random_ix]
print "X_train shape: ", X_train.shape
print "X_val.shape: ", X_val.shape
# Out:
# X_train shape:  (22717, 128)
# X_val.shape:  (1603, 128)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=100)
X_pca = pca.fit_transform(X_train)

# %%
X_pos = X_pca[y_train == 1, :]
X_neg = X_pca[y_train == 0, :]
(np.mean(X_pos, axis=0) - np.mean(X_neg, axis=0))
# Out:
# array([ -5.07544565e+00,   3.02108622e+00,  -2.13470295e-01,
#         -1.10637677e+00,   2.49226427e+00,   1.36908364e+00,
#         -1.61321020e+00,   3.10331845e+00,  -1.86853838e+00,
#         -6.77211732e-02,  -1.02939889e-01,  -8.33046496e-01,
#         -6.51081383e-01,   2.96854109e-01,  -7.67217755e-01,
#         -6.59664631e-01,   1.15371004e-01,  -6.62267923e-01,
#         -3.96697104e-01,  -6.49490952e-01,   1.83053827e-03,
#          2.65865147e-01,   3.49536538e-01,   2.14045763e-01,
#          3.05780053e-01,  -4.14612740e-01,  -4.95978802e-01,
#         -1.67914048e-01,  -1.06508948e-01,  -2.83773839e-02,
#          5.64846992e-01,  -4.90803152e-01,  -3.01305652e-01,
#         -1.84336543e-01,   8.79066885e-01,  -6.97460651e-01,
#         -4.74015065e-02,  -1.02073736e-01,   1.42840967e-01,
#          2.25536287e-01,   5.68501294e-01,   8.90421510e-01,
#          1.03111601e+00,  -6.07773900e-01,   1.01269983e-01,
#         -4.76356536e-01,   1.11292146e-01,   5.76298654e-01,
#         -9.34680045e-01,  -4.24607754e-01,   1.10607281e-01,
#          4.83815849e-01,   9.46575254e-02,   3.84236574e-01,
#         -5.83119914e-02,  -2.53585465e-02,   2.62786090e-01,
#         -2.02779844e-02,   4.75241065e-01,  -4.39098291e-02,
#          7.71543384e-02,   1.10160634e-01,  -1.14845991e-01,
#         -2.98435003e-01,   2.20461264e-02,   6.59638941e-02,
#         -9.28009450e-02,  -1.66338924e-02,  -1.68822668e-02,
#         -6.95191622e-02,   9.25239474e-02,   3.73734422e-02,
#         -1.38313312e-03,  -8.02158581e-07,   1.50882514e-07,
#          1.47859183e-07,  -1.58735645e-07,  -1.40921998e-07,
#         -9.95674156e-08,  -5.45212515e-08,   5.59191449e-08,
#         -1.26046771e-07,   8.55687716e-08,  -1.04872697e-08,
#         -1.19823497e-07,   8.83933460e-09,   1.28346400e-08,
#         -1.42752640e-07,   1.05752690e-07,  -5.75550487e-08,
#         -4.90312395e-08,   2.20244907e-08,   5.27375619e-08,
#          1.71671047e-07,  -2.73171850e-08,   1.88076967e-07,
#         -1.09178032e-07,  -5.15676462e-08,  -8.37324521e-08,
#          3.73192250e-08], dtype=float32)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.mixture import GMM
clf = RandomForestClassifier(n_estimators=50)
# clf = AdaBoostClassifier(n_estimators=100)
# clf = LogisticRegression()
# clf = SVC(probability=True)
clf.fit(X_pca, y_train)
#===[ Gaussian Mixture ]====
# clf = GMM(n_components=1, covariance_type='full')
# clf.fit(X_pos)
# Out:
# RandomForestClassifier(bootstrap=True, compute_importances=None,
#             criterion='gini', max_depth=None, max_features='auto',
#             min_density=None, min_samples_leaf=1, min_samples_split=2,
#             n_estimators=50, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0)

# %%
X_pca_val = pca.transform(X_val)
y_pred = clf.predict_proba(X_pca_val)[:,1]
print y_pred[y_val==1].mean()
print y_pred[y_val==0].mean()
# Out:
# 0.195387719406
# 0.164006620802

# %% [markdown]
# ## Evaluate clf

# %%
ix = 1
images = X_val_wy

# %%
image = images[ix,:,:,:].transpose(1,2,0).copy()
sift = cv2.SIFT(400)
pts = interesting_points(image)
pts = tuples2kpts(pts, size=3)
# X_0 = sift.compute(image[:,:,0], pts, None)[1]
# X_1 = sift.compute(image[:,:,1], pts, None)[1]
# X_2 = sift.compute(image[:,:,2], pts, None)[1]
# X_ = np.hstack([X_0, X_1, X_2])
X_ = sift.compute(image, pts, None)[1]
X_ = pca.transform(X_)
y_pred = clf.predict_proba(X_)[:,1]
ix += 1

# %%
from convcube.cv.keypoints import kpts2tuples
best_20_ix = np.argsort(y_pred)[:15]
best_20 = []
for ix in best_20_ix:
    best_20.append(pts[ix])
best_20 = kpts2tuples(best_20)

# %%
disp_img = image.copy()
pts_= kpts2tuples(pts)
for pt in best_20:
    x = int(pt[0])
    y = int(pt[1])
    disp_img[y-1:y+1, x-1:x+1, :]  = (255, 0, 0)
plt.imshow(disp_img[:,:,::-1])

# %% [markdown]
# ## Looking at Hough Lines Now

# %%
images = []
for i in range(400, 500):
    images.append(X_train_wy[i,:,:,:].transpose(1, 2, 0))
ix = 0

# %%
image = images[ix]
gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
edges = cv2.Canny(gray,50,200,apertureSize = 3)
# kernel = np.ones((2,2),np.uint8)
# closing = cv2.morphologyEx(edges, cv2.MORPH_CLOSE, kernel)
gaussian = cv2.GaussianBlur(edges, (3,3), 1)
on_ix = gaussian > 75
image[on_ix] = (0,0,0)
# closing[on_ix] = 1
# closing[~on_ix] = 0
# closing = closing.astype(np.float32) / closing.max()

# image = np.multiply(1 - closing, image.transpose(2, 0, 1)).transpose(1, 2, 0)

plt.imshow(image[:,:,::-1], cmap=plt.cm.gray)


ix += 1
# Out:
# (100, 100)

# %%
lines = cv2.HoughLinesP(edges,1,np.pi/180,100)
for rho,theta in lines[0]:
    a = np.cos(theta)
    b = np.sin(theta)
    x0 = a*rho
    y0 = b*rho
    x1 = int(x0 + 1000*(-b))
    y1 = int(y0 + 1000*(a))
    x2 = int(x0 - 1000*(-b))
    y2 = int(y0 - 1000*(a))

    cv2.line(img,(x1,y1),(x2,y2),(0,0,255),2)

cv2.imwrite('houghlines3.jpg',img)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-224-7adccb786857> in <module>()
#       1 lines = cv2.HoughLinesP(edges,1,np.pi/180,100)
# ----> 2 for rho,theta in lines[0]:
#       3     a = np.cos(theta)
#       4     b = np.sin(theta)
#       5     x0 = a*rho
#
# TypeError: 'NoneType' object has no attribute '__getitem__'

# %% [markdown]
# ## Add Contrast

# %%
images = []
for i in range(400, 500):
    images.append(X_train_wy[i,:,:,:].transpose(1, 2, 0))

ix = 0

# %%
# Out:
# 255.0

# %%
X_ = X_train_wy.copy()
def add_random_noise(X, std=1):
    """returns X with tint"""
    N = X.shape[0]
    X_noisy = np.zeros_like(X)
    for i in range(N):
        X_noisy[i, :, :, :] = X[i, :, :, :] + std*np.random.randn(*X[i,:,:,:].shape)
    X_noisy[X_noisy > 255] = 255
    return X_noisy

X_noisy = add_random_noise(X_)

# %%
plt.imshow(X_noisy[3,:,:,:].transpose(1, 2, 0)[:, :, ::-1])

# %%
x = X_[5,:,:,:]
plt.imshow(x.transpose(1, 2, 0)[:, :, ::-1])
