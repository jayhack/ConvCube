# %%
# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

#=====[ Standard + Math ]=====
import os
import sys
sys.path.insert(0, './') #for faster development
import pickle
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %pylab inline

#=====[ ModalDB ]=====
from ModalDB import ModalClient
from ModalDB import Video
from ModalDB import Frame

#=====[ convcube ]=====
from convcube.schema import convcube_schema
from convcube.cs231n.data_utils import load_tiny_imagenet
from convcube.localization import load_dataset_localization
from convcube.localization import LocalizationConvNet
from convcube.cube import ConvNetCube

#=====[ setup client ]=====
client = ModalClient('./data/db', schema=convcube_schema)
models_path = './models/localization'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# #I. Pretraining on ImageNet
# Skip this section if you can load an already-pretrained model

# %% [markdown]
# ### Get Data

# %%
imagenet_path = './convcube/cs231n/datasets/tiny-imagenet-100-A'
class_names, X_train, y_train, X_val, y_val, X_test, y_test = load_tiny_imagenet(imagenet_path)
print 'Train data shape: ', X_train.shape
print 'Train labels shape: ', y_train.shape
print 'Validation data shape: ', X_val.shape
print 'Validation labels shape: ', y_val.shape
print 'Test data shape: ', X_test.shape
# Out:
# loading training data for synset 20 / 100
# loading training data for synset 40 / 100
# loading training data for synset 60 / 100
# loading training data for synset 80 / 100
# loading training data for synset 100 / 100
# Train data shape:
#  (50000, 3, 64, 64)
# Train labels shape:  (50000,)
# Validation data shape:  (5000, 3, 64, 64)
# Validation labels shape:  (5000,)
# Test data shape:  (5000, 3, 64, 64)

# %% [markdown]
# ### Get Model

# %%
#=====[ LOAD MODEL ]=====
#*****
model_path = os.path.join(models_path, 'pretrained/convnet_10s.pkl')
pretrained_model = pickle.load(open(model_path))
#*****

# %%
#=====[ TRAIN MODEL ]=====
#*****
convnet = LocalizationConvNet()
model = convnet.init_pretrain_convnet()
model, loss_hist, train_acc_hist, val_acc_hist = convnet.pretrain(X_train, y_train, X_val, y_val)
pretrained_model = model
model_path = os.path.join(models_path, 'pretrained/convnet_10.pkl')
pickle.dump(pretrained_model, open(model_path, 'w'))
#*****
# Out:
# starting iteration  0
# Finished epoch 0 / 8: cost 4.871629, train: 0.012000, val 0.011200, lr 5.000000e-05
# starting iteration
#  10
# starting iteration
#  20
# starting iteration
#  30
# starting iteration
#  40
# starting iteration
#  50
# starting iteration
#  60
# starting iteration
#  70
# starting iteration
#  80
# starting iteration
#  90
# starting iteration
#  100
# starting iteration
#  110
# starting iteration
#  120
# starting iteration
#  130
# starting iteration
#  140
# starting iteration
#  150
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-0c058e55a5bf> in <module>()
#       3 convnet = LocalizationConvNet()
#       4 model = convnet.init_pretrain_convnet()
# ----> 5 model, loss_hist, train_acc_hist, val_acc_hist = convnet.pretrain(X_train, y_train, X_val, y_val)
#       6 #*****
#
# /Users/jayhack/Academics/CS/231N - CNN/Project/code/convcube/localization/convnet.py in pretrain(self, X_train, y_train, X_val, y_val, verbose)
#      96                                                                 dropout=None, reg=0.05, learning_rate=0.00005,
#      97                                                                 batch_size=50, num_epochs=8,
# ---> 98                                                                 learning_rate_decay=1.0, update='rmsprop', verbose=verbose
#      99 								)
#     100                 model, loss_hist, train_acc_hist, val_acc_hist = result
#
# /Users/jayhack/Academics/CS/231N - CNN/Project/code/convcube/cs231n/classifier_trainer.py in train(self, X, y, X_val, y_val, model, loss_function, reg, dropout, learning_rate, momentum, learning_rate_decay, update, sample_batches, num_epochs, batch_size, acc_frequency, augment_fn, predict_fn, verbose)
#      92
#      93       # evaluate cost and gradient
# ---> 94       cost, grads = loss_function(X_batch, model, y_batch, reg=reg, dropout=dropout)
#      95       loss_history.append(cost)
#      96
#
# /Users/jayhack/Academics/CS/231N - CNN/Project/code/convcube/cs231n/classifiers/convnet.py in three_layer_convnet(X, model, y, reg, dropout)
#     211     da2 = dropout_backward(dd2, cache3)
#     212   da1, dW2, db2 = affine_relu_backward(da2, cache2)
# --> 213   dX, dW1, db1 = conv_relu_pool_backward(da1, cache1)
#     214
#     215   grads = { 'W1': dW1, 'b1': db1, 'W2': dW2, 'b2': db2, 'W3': dW3, 'b3': db3 }
#
# /Users/jayhack/Academics/CS/231N - CNN/Project/code/convcube/cs231n/layer_utils.py in conv_relu_pool_backward(dout, cache)
#      57   ds = max_pool_backward_fast(dout, pool_cache)
#      58   da = relu_backward(ds, relu_cache)
# ---> 59   dx, dw, db = conv_backward_fast(da, conv_cache)
#      60   return dx, dw, db
#      61
#
# /Users/jayhack/Academics/CS/231N - CNN/Project/code/convcube/cs231n/fast_layers.py in conv_backward_strides(dout, cache)
#      95
#      96   dout_reshaped = dout.transpose(1, 0, 2, 3).reshape(F, -1)
# ---> 97   dw = dout_reshaped.dot(x_cols.T).reshape(w.shape)
#      98
#      99   dx_cols = w.reshape(F, -1).T.dot(dout_reshaped)
#
# KeyboardInterrupt:

# %% [markdown]
# #II. Transfer Learning on Rubiks Cubes

# %% [markdown]
# ### Get Data

# %%
X_train, X_val, y_train, y_val = load_dataset_localization(client, train_size=0.8)
print 'Train data shape: ', X_train.shape
print 'Train labels shape: ', y_train.shape
print 'Validation data shape: ', X_val.shape
print 'Validation labels shape: ', y_val.shape
# Out:
# Train data shape:  (312, 3, 46, 80)
# Train labels shape:  (312, 2)
# Validation data shape:  (79, 3, 46, 80)
# Validation labels shape:  (79, 2)

# %% [markdown]
# ### Get Model

# %%
#=====[ LOAD MODEL ]=====
#*****
model_path = os.path.join(models_path, 'transferred/convnet_10s.pkl')
model = pickle.load(open(model_path))
#*****

# %%
#=====[ TRAIN MODEL ]=====
#*****
convnet = LocalizationConvNet()

out = convnet.train_localization_convnet(   
                                            X_train, y_train,
                                            X_val, y_val,
                                            pretrained_model,

                                        )
model, loss_hist, train_acc_hist, val_acc_hist = out
pickle.dump(model, open('models/localization/transferred/convnet_10s.pkl', 'w'))
#*****
# Out:
# starting iteration  0
# NEW BEST MODEL
# Finished epoch 0 / 30: cost 0.364269, train: 0.120576, val 0.111115, lr 5.000000e-05
# NEW BEST MODEL
# Finished epoch 1 / 30: cost 0.122111, train: 0.064545, val 0.063361, lr 5.000000e-05
# starting iteration
#  10
# NEW BEST MODEL
# Finished epoch 2 / 30: cost 0.110654, train: 0.045116, val 0.049618, lr 5.000000e-05
# NEW BEST MODEL
# Finished epoch 3 / 30: cost 0.090905, train: 0.037220, val 0.043662, lr 5.000000e-05
# starting iteration
#  20
# NEW BEST MODEL
# Finished epoch 4 / 30: cost 0.063807, train: 0.029739, val 0.039647, lr 5.000000e-05
# NEW BEST MODEL
# Finished epoch 5 / 30: cost 0.075381, train: 0.026747, val 0.038707, lr 5.000000e-05
# starting iteration  30
# NEW BEST MODEL
# Finished epoch 6 / 30: cost 0.064413, train: 0.021667, val 0.032456, lr 5.000000e-05
# starting iteration
#  40
# NEW BEST MODEL
# Finished epoch 7 / 30: cost 0.064292, train: 0.020932, val 0.031411, lr 5.000000e-05
# NEW BEST MODEL
# Finished epoch 8 / 30: cost 0.053326, train: 0.017829, val 0.030146, lr 5.000000e-05
# starting iteration
#  50
# NEW BEST MODEL
# Finished epoch 9 / 30: cost 0.057287, train: 0.016199, val 0.029785, lr 5.000000e-05
# NEW BEST MODEL
# Finished epoch 10 / 30: cost 0.061159, train: 0.016591, val 0.028328, lr 5.000000e-05
# starting iteration  60
# Finished epoch 11 / 30: cost 0.062722, train: 0.014308, val 0.029013, lr 5.000000e-05
# starting iteration
#  70
# Finished epoch 12 / 30: cost 0.059185, train: 0.013790, val 0.029252, lr 5.000000e-05
# Finished epoch 13 / 30: cost 0.058121, train: 0.018573, val 0.034687, lr 5.000000e-05
# starting iteration
#  80
# NEW BEST MODEL
# Finished epoch 14 / 30: cost 0.048081, train: 0.011055, val 0.024192, lr 5.000000e-05
# NEW BEST MODEL
# Finished epoch 15 / 30: cost 0.043468, train: 0.011314, val 0.023402, lr 5.000000e-05
# starting iteration  90
# Finished epoch 16 / 30: cost 0.042175, train: 0.011783, val 0.023692, lr 5.000000e-05
# starting iteration
#  100
# NEW BEST MODEL
# Finished epoch 17 / 30: cost 0.046534, train: 0.009977, val 0.022456, lr 5.000000e-05
# NEW BEST MODEL
# Finished epoch 18 / 30: cost 0.038572, train: 0.008835, val 0.022089, lr 5.000000e-05
# starting iteration
#  110
# NEW BEST MODEL
# Finished epoch 19 / 30: cost 0.041149, train: 0.008666, val 0.021301, lr 5.000000e-05
# Finished epoch 20 / 30: cost 0.038135, train: 0.009722, val 0.021595, lr 5.000000e-05
# starting iteration  120
# Finished epoch 21 / 30: cost 0.035423, train: 0.008760, val 0.021387, lr 5.000000e-05
# starting iteration
#  130
# Finished epoch 22 / 30: cost 0.044821, train: 0.010853, val 0.022926, lr 5.000000e-05
# NEW BEST MODEL
# Finished epoch 23 / 30: cost 0.039041, train: 0.008485, val 0.020975, lr 5.000000e-05
# starting iteration
#  140
# NEW BEST MODEL
# Finished epoch 24 / 30: cost 0.038367, train: 0.007250, val 0.020546, lr 5.000000e-05
# NEW BEST MODEL
# Finished epoch 25 / 30: cost 0.033107, train: 0.006959, val 0.020254, lr 5.000000e-05
# starting iteration  150
# Finished epoch 26 / 30: cost 0.034731, train: 0.006961, val 0.020445, lr 5.000000e-05
# starting iteration
#  160
# Finished epoch 27 / 30: cost 0.040711, train: 0.009547, val 0.021969, lr 5.000000e-05
# Finished epoch 28 / 30: cost 0.034034, train: 0.007845, val 0.020530, lr 5.000000e-05
# starting iteration
#  170
# Finished epoch 29 / 30: cost 0.036897, train: 0.007010, val 0.022564, lr 5.000000e-05
# NEW BEST MODEL
# Finished epoch 30 / 30: cost 0.031190, train: 0.005464, val 0.020076, lr 5.000000e-05
# finished optimization. best validation accuracy: 0.020076

# %% [markdown]
# ### Visualize Loss

# %%
import seaborn as sns
plt.plot(train_acc_hist[5:])
plt.plot(val_acc_hist[5:])
plt.xlabel('Training Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss During Training')

# %% [markdown]
# ### Visualize Cost

# %%
plt.plot(loss_hist[20:])
plt.xlabel('Training Epoch')
plt.ylabel('Loss')
plt.title('loss hist over training')

# %% [markdown]
# #III. Visualizing Results

# %%
from convcube import ConvNetCube
from convcube.utils.wrangling import iter_unlabeled_frames
from convcube.utils.wrangling import iter_labeled_frames
from convcube.localization.utils import get_y_localization
from convcube.localization.utils import get_X_localization
from convcube.utils.drawing import draw_points
cube = ConvNetCube(loc_model=model)

# %% [markdown]
# ### On Labeled Frames

# %%
model = pickle.load(open('models/localization/transferred/convnet_10s.pkl'))
convnet = LocalizationConvNet()
scores = convnet.localization_convnet(X_val, model)
print np.sqrt(np.sum((scores - y_val)**2, axis=1))
# Out:
# [ 0.03716004  0.17207989  0.10710659  0.14514105  0.04581057  0.1102067
#   0.12642622  0.05819591  0.07791165  0.0665393   0.03240623  0.02904457
#   0.44703925  0.08604831  0.07126968  0.02895059  0.04885501  0.18838654
#   0.0009571   0.16348715  0.04065805  0.14634624  0.16078734  0.05800656
#   0.0244571   0.06895117  0.13762727  0.66690052  0.09969926  0.30577362
#   0.1211904   0.0205446   0.05981954  0.09438157  0.07697694  0.09150495
#   0.07326575  0.0499443   0.10436296  0.10177882  0.13921659  0.10932641
#   0.09166643  0.09551781  0.11408722  0.02000746  0.10135502  0.02783059
#   0.15896282  0.10959536  0.05662429  0.04318108  0.06340726  0.07917261
#   0.11024852  0.22213106  0.14603776  0.13298774  0.0112023   0.00458068
#   0.06294679  0.03244884  0.07790871  0.11845873  0.16771698  0.04428547
#   0.15114258  0.06454806  0.08913392  0.07374098  0.1262311   0.21793874
#   0.0670089   0.02472854  0.13751157  0.10631865  0.04917938  0.08070965
#   0.16022313]

# %%
convnet = LocalizationConvNet()
scores = convnet.localization_convnet(X_val, model)


for frame in iter_labeled_frames(client):

    image = frame['image'].copy()
    kpts = frame['interior_points']
    X = get_X_localization(frame['image'])
    y = get_y_localization(frame['interior_points'])
    y_pred = convnet.localization_convnet(X, model)[0]
#     print y, y_pred, abs(y-y_pred)
    
    y_pred[0] = y_pred[0] * 640
    y_pred[1] = y_pred[1] * 360

    y[0] = y[0] * 640
    y[1] = y[1] * 360
    print y, y_pred

    disp_img = image.copy()
    cv2.circle(disp_img, (int(y[0]), int(y[1])), 5, color=(0, 255, 0), thickness=2)
    cv2.circle(disp_img, (int(y_pred[0]), int(y_pred[1])), 5, color=(0, 0, 255), thickness=2)
    plt.imshow(disp_img[:,:,::-1])

    break
    #     print frame['interior_points']
#     X = get_X_localization(frame['image'])
#     loss, grads = conv.localization_convnet(X, model, y=y)
#     print loss, grads
# Out:
# [ 398.5  180. ] [ 360.30273438  206.05577087]
