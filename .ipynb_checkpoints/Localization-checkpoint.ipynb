# %%
# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

#=====[ Standard + Math ]=====
import os
import sys
sys.path.insert(0, './') #for faster development
import pickle
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %pylab inline

#=====[ ModalDB ]=====
from ModalDB import ModalClient
from ModalDB import Video
from ModalDB import Frame

#=====[ convcube ]=====
from convcube.db import dbschema
from convcube.cs231n.data_utils import load_tiny_imagenet
from convcube.convnets import load_dataset_localization
from convcube.convnets import EuclideanConvNet
from convcube.cube import ConvNetCube

#=====[ setup client ]=====
client = ModalClient('./data/db', schema=dbschema)
models_path = './models/'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## I. Transfer Learning on Rubiks Cubes

# %% [markdown]
# ### Get Pretrained Model

# %%
#=====[ LOAD MODEL ]=====
#*****
model_path = os.path.join(models_path, 'pretrained/convnet_16s.pkl')
pretrained_model = pickle.load(open(model_path))
#*****

# %% [markdown]
# ### Get Data

# %%
X_train, X_val, y_train, y_val = load_dataset_localization(client, train_size=0.8)
print 'Train data shape: ', X_train.shape
print 'Train labels shape: ', y_train.shape
print 'Validation data shape: ', X_val.shape
print 'Validation labels shape: ', y_val.shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-107-64e61493416f> in <module>()
# ----> 1 X_train, X_val, y_train, y_val = load_dataset_localization(client, train_size=0.9)
#       2 print 'Train data shape: ', X_train.shape
#       3 print 'Train labels shape: ', y_train.shape
#       4 print 'Validation data shape: ', X_val.shape
#       5 print 'Validation labels shape: ', y_val.shape
#
# /Users/jayhack/Academics/CS/231N - CNN/Project/code/convcube/convnets/localization.py in load_dataset_localization(client, train_size)
#      62         X_train = np.vstack(itertools.chain(*X[:split_ix]))
#      63         y_train = np.vstack(itertools.chain(*y[:split_ix]))
# ---> 64         X_val = np.vstack(itertools.chain(*X[split_ix:]))
#      65         y_val = np.vstack(itertools.chain(*y[split_ix:]))
#      66
#
# /Users/jayhack/anaconda/lib/python2.7/site-packages/numpy/core/shape_base.pyc in vstack(tup)
#     226
#     227     """
# --> 228     return _nx.concatenate([atleast_2d(_m) for _m in tup], 0)
#     229
#     230 def hstack(tup):
#
# ValueError: need at least one array to concatenate

# %% [markdown]
# ### Train Model

# %%
#=====[ TRAIN MODEL ]=====
#*****
convnet = EuclideanConvNet(     
                                pretrained_model=None,
                                size_out=4, #two x,y coords
                                num_filters_loc=(10, 10, 10, 32),
                                filter_sizes_loc=(5, 5, 5),
                                shape_loc=(3, 64, 64)
                           )
out = convnet.train(X_train, y_train, X_val, y_val,
                    pretrain=False,
                    batch_size=50,
                    num_epochs=40,
                    learning_rate=0.0001,
                    learning_rate_decay=0.95
                    )
model, loss_hist, train_acc_hist, val_acc_hist = out
convnet.save('models/localization/16s.loc_convnet_border')
#*****
# Out:
# starting iteration  0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-54-91de9c3465c0> in <module>()
#      13                     num_epochs=40,
#      14                     learning_rate=0.0001,
# ---> 15                     learning_rate_decay=0.95
#      16                     )
#      17 model, loss_hist, train_acc_hist, val_acc_hist = out
#
# /Users/jayhack/Academics/CS/231N - CNN/Project/code/convcube/convnets/euclidean.py in train(self, X_train, y_train, X_val, y_val, pretrain, dropout, reg, learning_rate, batch_size, num_epochs, learning_rate_decay, update, verbose)
#     398                                                                                                                                                 batch_size=batch_size, num_epochs=num_epochs,
#     399                                                                                                                                                 learning_rate_decay=learning_rate_decay,
# --> 400                                                                                                                                                 update=update, verbose=verbose
#     401 																	)
#     402                 self.model = model
#
# /Users/jayhack/Academics/CS/231N - CNN/Project/code/convcube/convnets/euclidean_trainer.pyc in train(self, X, y, X_val, y_val, model, loss_function, reg, dropout, learning_rate, momentum, learning_rate_decay, update, sample_batches, num_epochs, batch_size, acc_frequency, augment_fn, predict_fn, verbose)
#     154             X_train_slice = predict_fn(X_train_slice)
#     155
# --> 156           scores = loss_function(X_train_slice, model) #(batch_size x 2) array of predicted coordinates
#     157           y_pred_train.append(scores)
#     158
#
# /Users/jayhack/Academics/CS/231N - CNN/Project/code/convcube/convnets/euclidean.py in transfer_convnet(self, X, model, y, reg, dropout)
#     333
#     334                 #=====[ Step 2: Forward pass    ]=====
# --> 335                 a1, cache1 = conv_relu_pool_forward(X, W1, b1, conv_param_1, pool_param)
#     336                 a2, cache2 = conv_relu_pool_forward(a1, W2, b2, conv_param_2, pool_param)
#     337                 a3, cache3 = conv_relu_pool_forward(a2, W3, b3, conv_param_3, pool_param)
#
# /Users/jayhack/Academics/CS/231N - CNN/Project/code/convcube/cs231n/layer_utils.pyc in conv_relu_pool_forward(x, w, b, conv_param, pool_param)
#      44   """
#      45   a, conv_cache = conv_forward_fast(x, w, b, conv_param)
# ---> 46   s, relu_cache = relu_forward(a)
#      47   out, pool_cache = max_pool_forward_fast(s, pool_param)
#      48   cache = (conv_cache, relu_cache, pool_cache)
#
# /Users/jayhack/Academics/CS/231N - CNN/Project/code/convcube/cs231n/layers.pyc in relu_forward(x)
#      56   - cache: x
#      57   """
# ---> 58   out = np.maximum(0, x)
#      59   cache = x
#      60   return out, cache
#
# KeyboardInterrupt:

# %% [markdown]
# ### Visualize Loss

# %%
plt.plot(train_acc_hist[5:])
plt.plot(val_acc_hist[5:])
plt.xlabel('Training Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss During Training')

# %% [markdown]
# #II. Visualizing Results

# %%
from convcube import ConvNetCube
from convcube.utils.wrangling import iter_unlabeled_frames
from convcube.utils.wrangling import iter_labeled_frames
from convcube.convnets.localization import get_y_localization
from convcube.convnets.localization import get_X_localization
from convcube.utils.drawing import draw_points
loc_convnet = EuclideanConvNet()
loc_convnet.load('./models/localization/filter_555.nfilters_101010.center_scale.acc_005.convnet')
cube = ConvNetCube(loc_convnet=loc_convnet)

# %% [markdown]
# ### Draw on Random Frame

# %%
video = client.get(Video, 'lanthrop_4')
frame = video.get_random_child(Frame)
image = frame['image'].copy()
disp_img = cube.draw_output(image)
plt.imshow(disp_img[:,:,::-1])

# %% [markdown]
# ## Timeit

# %%
# %timeit cube.localize(image)
# Out:
# 100 loops, best of 3: 7.1 ms per loop
