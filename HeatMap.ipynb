# %%
# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

#=====[ Standard + Math ]=====
import os
import sys
sys.path.insert(0, './') #for faster development
import pickle
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %pylab inline

#=====[ ModalDB ]=====
from ModalDB import ModalClient
from ModalDB import Video
from ModalDB import Frame

#=====[ convcube ]=====
from convcube.db import dbschema
from convcube.heatmapping import load_dataset_heatmap
from convcube.heatmapping import HeatmapConvNet
from convcube import ConvNetCube

#=====[ setup client ]=====
client = ModalClient('./data/db', schema=dbschema)
models_path = './models/localization'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Get Data

# %%
X_train, X_val, y_train, y_val = load_dataset_heatmap(client, train_size=0.9)
print 'Train data shape: ', X_train.shape
print 'Train labels shape: ', y_train.shape
print 'Validation data shape: ', X_val.shape
print 'Validation labels shape: ', y_val.shape
# Out:
# Train data shape:  (354, 3, 46, 80)
# Train labels shape:  (354, 8)
# Validation data shape:  (40, 3, 46, 80)
# Validation labels shape:  (40, 8)

# %% [markdown]
# ## Visualize Data

# %%
img = X_train[ix,:,:,:].copy()
img = img.sum(axis=0)
plt.imshow(img, cmap=plt.cm.gray)
ix += 1

# %%
label = y_train[ix,:]
label = label.reshape((46, 80))
plt.imshow(label, cmap=plt.cm.gray)

# %% [markdown]
# ## Get Pretrained Model

# %%
#=====[ LOAD MODEL ]=====
#*****
model_path = os.path.join(models_path, 'pretrained/convnet_10s.pkl')
pretrained_model = pickle.load(open(model_path))
#*****

# %% [markdown]
# ## Transfer Learning

# %%
#=====[ LOAD MODEL ]=====
#*****
convnet = HeatmapConvNet()
convnet.load('models/localization/10s.loc_convnet')
#*****

# %%
#=====[ TRAIN MODEL ]=====
#*****
convnet = HeatmapConvNet(pretrained_model=pretrained_model)
out = convnet.train(X_train, y_train, X_val, y_val)
model, loss_hist, train_acc_hist, val_acc_hist = out
convnet.save('models/heatmapping/10s.hmp_convnet')
#*****
# Out:
# starting iteration  0
# Finished epoch 0 / 50: cost 1.247221, train: 11878.158487, val 11084.616040, lr 5.000000e-04
# Finished epoch 1 / 50: cost 0.640506, train: 0.862743, val 0.832878, lr 5.000000e-04
# starting iteration
#  10
# Finished epoch 2 / 50: cost 0.321864, train: 0.524674, val 0.601641, lr 5.000000e-04
# starting iteration
#  20
# Finished epoch 3 / 50: cost 0.296338, train: 0.393080, val 0.457855, lr 5.000000e-04
# Finished epoch 4 / 50: cost 0.281180, train: 0.357696, val 0.435392, lr 5.000000e-04
# starting iteration
#  30
# Finished epoch 5 / 50: cost 0.294261, train: 0.339589, val 0.417599, lr 5.000000e-04
# starting iteration
#  40
# Finished epoch 6 / 50: cost 0.273584, train: 0.314033, val 0.410062, lr 5.000000e-04
# Finished epoch 7 / 50: cost 0.211110, train: 0.293205, val 0.382730, lr 5.000000e-04
# starting iteration
#  50
# Finished epoch 8 / 50: cost 0.273439, train: 0.283071, val 0.370483, lr 5.000000e-04
# starting iteration
#  60
# Finished epoch 9 / 50: cost 0.237505, train: 0.260658, val 0.356924, lr 5.000000e-04
# Finished epoch 10 / 50: cost 0.218519, train: 0.248627, val 0.338431, lr 5.000000e-04
# starting iteration  70
# Finished epoch 11 / 50: cost 0.225602, train: 0.289302, val 0.360395, lr 5.000000e-04
# starting iteration
#  80
# Finished epoch 12 / 50: cost 0.343427, train: 0.431900, val 0.497227, lr 5.000000e-04
# starting iteration
#  90
# Finished epoch 13 / 50: cost 0.213619, train: 0.231950, val 0.342791, lr 5.000000e-04
# Finished epoch 14 / 50: cost 0.213203, train: 0.219737, val 0.331386, lr 5.000000e-04
# starting iteration
#  100
# Finished epoch 15 / 50: cost 0.222454, train: 0.233865, val 0.330614, lr 5.000000e-04
# starting iteration
#  110
# Finished epoch 16 / 50: cost 0.200141, train: 0.207774, val 0.317628, lr 5.000000e-04
# Finished epoch 17 / 50: cost 0.207251, train: 0.204499, val 0.323215, lr 5.000000e-04
# starting iteration
#  120
# Finished epoch 18 / 50: cost 0.240344, train: 0.213682, val 0.326263, lr 5.000000e-04
# starting iteration
#  130
# Finished epoch 19 / 50: cost 0.190971, train: 0.193902, val 0.331741, lr 5.000000e-04
# Finished epoch 20 / 50: cost 0.206253, train: 0.196389, val 0.339050, lr 5.000000e-04
# starting iteration  140
# Finished epoch 21 / 50: cost 0.218735, train: 0.272344, val 0.375555, lr 5.000000e-04
# starting iteration
#  150
# Finished epoch 22 / 50: cost 0.203062, train: 0.196413, val 0.336442, lr 5.000000e-04
# starting iteration
#  160
# Finished epoch 23 / 50: cost 0.215086, train: 0.186104, val 0.337142, lr 5.000000e-04
# Finished epoch 24 / 50: cost 0.194595, train: 0.185337, val 0.326350, lr 5.000000e-04
# starting iteration
#  170
# Finished epoch 25 / 50: cost 0.218967, train: 0.205133, val 0.360407, lr 5.000000e-04
# starting iteration
#  180
# Finished epoch 26 / 50: cost 0.330830, train: 0.419799, val 0.484795, lr 5.000000e-04
# Finished epoch 27 / 50: cost 0.217779, train: 0.178095, val 0.333961, lr 5.000000e-04
# starting iteration
#  190
# Finished epoch 28 / 50: cost 0.170804, train: 0.173053, val 0.345311, lr 5.000000e-04
# starting iteration
#  200
# Finished epoch 29 / 50: cost 0.178993, train: 0.170028, val 0.333555, lr 5.000000e-04
# Finished epoch 30 / 50: cost 0.182936, train: 0.164877, val 0.338496, lr 5.000000e-04
# starting iteration  210
# Finished epoch 31 / 50: cost 0.200625, train: 0.168477, val 0.354433, lr 5.000000e-04
# starting iteration
#  220
# Finished epoch 32 / 50: cost 0.204565, train: 0.177573, val 0.332746, lr 5.000000e-04
# starting iteration
#  230
# Finished epoch 33 / 50: cost 0.185755, train: 0.188392, val 0.390574, lr 5.000000e-04
# Finished epoch 34 / 50: cost 0.219233, train: 0.214348, val 0.362633, lr 5.000000e-04
# starting iteration
#  240
# Finished epoch 35 / 50: cost 0.207778, train: 0.174038, val 0.363926, lr 5.000000e-04
# starting iteration
#  250
# Finished epoch 36 / 50: cost 0.165376, train: 0.157461, val 0.347885, lr 5.000000e-04
# Finished epoch 37 / 50: cost 0.182167, train: 0.153417, val 0.338194, lr 5.000000e-04
# starting iteration
#  260
# Finished epoch 38 / 50: cost 0.203349, train: 0.168550, val 0.372247, lr 5.000000e-04
# starting iteration
#  270
# Finished epoch 39 / 50: cost 0.222836, train: 0.271274, val 0.395717, lr 5.000000e-04
# Finished epoch 40 / 50: cost 0.203324, train: 0.175676, val 0.394994, lr 5.000000e-04
# starting iteration  280
# Finished epoch 41 / 50: cost 0.180248, train: 0.150258, val 0.365729, lr 5.000000e-04
# starting iteration
#  290
# Finished epoch 42 / 50: cost 0.186258, train: 0.142492, val 0.352191, lr 5.000000e-04
# starting iteration
#  300
# Finished epoch 43 / 50: cost 0.165175, train: 0.142049, val 0.356988, lr 5.000000e-04
# Finished epoch 44 / 50: cost 0.179668, train: 0.148370, val 0.353610, lr 5.000000e-04
# starting iteration
#  310
# Finished epoch 45 / 50: cost 0.281100, train: 0.251391, val 0.463621, lr 5.000000e-04
# starting iteration
#  320
# Finished epoch 46 / 50: cost 0.205730, train: 0.177610, val 0.349007, lr 5.000000e-04
# Finished epoch 47 / 50: cost 0.200608, train: 0.159646, val 0.388315, lr 5.000000e-04
# starting iteration
#  330
# Finished epoch 48 / 50: cost 0.155138, train: 0.146723, val 0.345097, lr 5.000000e-04
# starting iteration
#  340
# Finished epoch 49 / 50: cost 0.197367, train: 0.136785, val 0.362519, lr 5.000000e-04
# Finished epoch 50 / 50: cost 0.156975, train: 0.131005, val 0.363993, lr 5.000000e-04
# finished optimization. best validation accuracy: 0.317628

# %%
plt.plot(train_acc_hist)

# %% [markdown]
# ## Visualize Results

# %%
y_pred = convnet.predict(X_val)

# %%
img = X_val[10,:,:,:].copy().sum(axis=0)
plt.imshow(img, cmap=plt.cm.gray)

# %%
pts = y_pred[10,:]
print pts
# Out:
# [ 0.78942257  0.59352064  0.83865541  0.88408971  0.63018054  0.74469626
#   0.66969711  0.67757708]
