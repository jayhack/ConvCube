# %%
# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

#=====[ Standard + Math ]=====
import os
import sys
sys.path.insert(0, './') #for faster development
import pickle
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %pylab inline

#=====[ ModalDB ]=====
from ModalDB import ModalClient
from ModalDB import Video
from ModalDB import Frame

#=====[ convcube ]=====
from convcube.db import dbschema
from convcube.heatmapping import load_dataset_heatmap
from convcube.heatmapping import HeatmapConvNet
from convcube import ConvNetCube

#=====[ setup client ]=====
client = ModalClient('./data/db', schema=dbschema)
models_path = './models/localization'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Get Data

# %%
X_train, X_val, y_train, y_val = load_dataset_heatmap(client, train_size=0.9)
print 'Train data shape: ', X_train.shape
print 'Train labels shape: ', y_train.shape
print 'Validation data shape: ', X_val.shape
print 'Validation labels shape: ', y_val.shape
# Out:
# Train data shape:  (651, 3, 46, 80)
# Train labels shape:  (651, 3680)
# Validation data shape:  (73, 3, 46, 80)
# Validation labels shape:  (73, 3680)

# %% [markdown]
# ## Visualize Data

# %%
img = X_train[ix,:,:,:].copy()
img = img.sum(axis=0)
plt.imshow(img, cmap=plt.cm.gray)
ix += 1

# %%
label = y_train[ix,:]
label = label.reshape((46, 80))
plt.imshow(label, cmap=plt.cm.gray)

# %% [markdown]
# ## Get Pretrained Model

# %%
#=====[ LOAD MODEL ]=====
#*****
model_path = os.path.join(models_path, 'pretrained/convnet_10s.pkl')
pretrained_model = pickle.load(open(model_path))
#*****

# %% [markdown]
# ## Transfer Learning

# %%
#=====[ LOAD MODEL ]=====
#*****
convnet = HeatmapConvNet()
convnet.load('models/localization/10s.loc_convnet')
#*****

# %%
#=====[ TRAIN MODEL ]=====
#*****
convnet = HeatmapConvNet(pretrained_model=pretrained_model)
out = convnet.train(X_train, y_train, X_val, y_val)
model, loss_hist, train_acc_hist, val_acc_hist = out
convnet.save('models/heatmapping/10s.hmp_convnet')
#*****
# Out:
# starting iteration  0
# Finished epoch 0 / 50: cost 11.334805, train: 40.551971, val 39.664001, lr 5.000000e-04
# starting iteration
#  10
# Finished epoch 1 / 50: cost 2.499528, train: 23.886179, val 24.808399, lr 5.000000e-04
# starting iteration
#  20
# Finished epoch 2 / 50: cost 2.283692, train: 23.666309, val 24.595451, lr 5.000000e-04
# starting iteration
#  30
# Finished epoch 3 / 50: cost 2.413560, train: 23.548098, val 24.486103, lr 5.000000e-04
# starting iteration
#  40
# starting iteration
#  50
# Finished epoch 4 / 50: cost 2.484276, train: 23.469164, val 24.410276, lr 5.000000e-04
# starting iteration
#  60
# Finished epoch 5 / 50: cost 2.327134, train: 23.423840, val 24.371023, lr 5.000000e-04
# starting iteration
#  70
# Finished epoch 6 / 50: cost 2.340825, train: 23.389780, val 24.341270, lr 5.000000e-04
# starting iteration
#  80
# starting iteration
#  90
# Finished epoch 7 / 50: cost 2.295556, train: 23.368883, val 24.318865, lr 5.000000e-04
# starting iteration
#  100
# Finished epoch 8 / 50: cost 2.334093, train: 23.353653, val 24.311594, lr 5.000000e-04
# starting iteration
#  110
# Finished epoch 9 / 50: cost 2.430865, train: 23.343014, val 24.301033, lr 5.000000e-04
# starting iteration
#  120
# Finished epoch 10 / 50: cost 2.350754, train: 23.334814, val 24.300396, lr 5.000000e-04
# starting iteration  130
# starting iteration
#  140
# Finished epoch 11 / 50: cost 2.307484, train: 23.330542, val 24.289526, lr 5.000000e-04
# starting iteration
#  150
# Finished epoch 12 / 50: cost 2.379385, train: 23.325943, val 24.295008, lr 5.000000e-04
# starting iteration
#  160
# Finished epoch 13 / 50: cost 2.296931, train: 23.323118, val 24.295704, lr 5.000000e-04
# starting iteration
#  170
# starting iteration
#  180
# Finished epoch 14 / 50: cost 2.309710, train: 23.321999, val 24.291849, lr 5.000000e-04
# starting iteration
#  190
# Finished epoch 15 / 50: cost 2.266575, train: 23.321081, val 24.293715, lr 5.000000e-04
# starting iteration
#  200
# Finished epoch 16 / 50: cost 2.380580, train: 23.319948, val 24.288031, lr 5.000000e-04
# starting iteration
#  210
# starting iteration
#  220
# Finished epoch 17 / 50: cost 2.261658, train: 23.319332, val 24.282555, lr 5.000000e-04
# starting iteration
#  230
# Finished epoch 18 / 50: cost 2.330943, train: 23.319262, val 24.287840, lr 5.000000e-04
# starting iteration
#  240
# Finished epoch 19 / 50: cost 2.403729, train: 23.319460, val 24.298458, lr 5.000000e-04
# starting iteration
#  250
# Finished epoch 20 / 50: cost 2.260848, train: 23.319487, val 24.302118, lr 5.000000e-04
# starting iteration  260
# starting iteration
#  270
# Finished epoch 21 / 50: cost 2.457805, train: 23.320042, val 24.299131, lr 5.000000e-04
# starting iteration
#  280
# Finished epoch 22 / 50: cost 2.412396, train: 23.319614, val 24.301580, lr 5.000000e-04
# starting iteration
#  290
# Finished epoch 23 / 50: cost 2.256772, train: 23.319252, val 24.301767, lr 5.000000e-04
# starting iteration
#  300
# starting iteration
#  310
# Finished epoch 24 / 50: cost 2.377276, train: 23.319359, val 24.299126, lr 5.000000e-04
# starting iteration
#  320
# Finished epoch 25 / 50: cost 2.293950, train: 23.319960, val 24.294632, lr 5.000000e-04
# starting iteration
#  330
# Finished epoch 26 / 50: cost 2.263185, train: 23.320288, val 24.291029, lr 5.000000e-04
# starting iteration
#  340
# starting iteration
#  350
# Finished epoch 27 / 50: cost 2.400065, train: 23.319567, val 24.290512, lr 5.000000e-04
# starting iteration
#  360
# Finished epoch 28 / 50: cost 2.357562, train: 23.318979, val 24.284210, lr 5.000000e-04
# starting iteration
#  370
# Finished epoch 29 / 50: cost 2.304486, train: 23.319899, val 24.285902, lr 5.000000e-04
# starting iteration
#  380
# Finished epoch 30 / 50: cost 2.500133, train: 23.321781, val 24.289370, lr 5.000000e-04
# starting iteration  390
# starting iteration
#  400
# Finished epoch 31 / 50: cost 2.347188, train: 23.320059, val 24.290186, lr 5.000000e-04
# starting iteration
#  410
# Finished epoch 32 / 50: cost 2.187671, train: 23.320341, val 24.291359, lr 5.000000e-04
# starting iteration
#  420
# Finished epoch 33 / 50: cost 2.388406, train: 23.320799, val 24.290625, lr 5.000000e-04
# starting iteration
#  430
# starting iteration
#  440
# Finished epoch 34 / 50: cost 2.397369, train: 23.320110, val 24.292408, lr 5.000000e-04
# starting iteration
#  450
# Finished epoch 35 / 50: cost 2.285402, train: 23.320162, val 24.295681, lr 5.000000e-04
# starting iteration
#  460
# Finished epoch 36 / 50: cost 2.359410, train: 23.320045, val 24.298582, lr 5.000000e-04
# starting iteration
#  470
# starting iteration
#  480
# Finished epoch 37 / 50: cost 2.364146, train: 23.320244, val 24.301224, lr 5.000000e-04
# starting iteration
#  490
# Finished epoch 38 / 50: cost 2.347812, train: 23.320103, val 24.296066, lr 5.000000e-04
# starting iteration
#  500
# Finished epoch 39 / 50: cost 2.379633, train: 23.320017, val 24.287968, lr 5.000000e-04
# starting iteration
#  510
# Finished epoch 40 / 50: cost 2.368843, train: 23.319750, val 24.285418, lr 5.000000e-04
# starting iteration  520
# starting iteration
#  530
# Finished epoch 41 / 50: cost 2.543734, train: 23.320024, val 24.291527, lr 5.000000e-04
# starting iteration
#  540
# Finished epoch 42 / 50: cost 2.465252, train: 23.321312, val 24.287544, lr 5.000000e-04
# starting iteration
#  550
# Finished epoch 43 / 50: cost 2.518992, train: 23.321007, val 24.292809, lr 5.000000e-04
# starting iteration
#  560
# starting iteration
#  570
# Finished epoch 44 / 50: cost 2.330856, train: 23.321186, val 24.296776, lr 5.000000e-04
# starting iteration
#  580
# Finished epoch 45 / 50: cost 2.327351, train: 23.321810, val 24.290833, lr 5.000000e-04
# starting iteration
#  590
# Finished epoch 46 / 50: cost 2.328852, train: 23.321140, val 24.303692, lr 5.000000e-04
# starting iteration
#  600
# starting iteration
#  610
# Finished epoch 47 / 50: cost 2.334341, train: 23.320625, val 24.294136, lr 5.000000e-04
# starting iteration
#  620
# Finished epoch 48 / 50: cost 2.328035, train: 23.321430, val 24.288998, lr 5.000000e-04
# starting iteration
#  630
# Finished epoch 49 / 50: cost 2.216580, train: 23.321001, val 24.286545, lr 5.000000e-04
# starting iteration
#  640
# Finished epoch 50 / 50: cost 2.231921, train: 23.319918, val 24.290113, lr 5.000000e-04
# finished optimization. best validation accuracy: 24.282555

# %% [markdown]
# ## Visualize Results

# %%
y_pred = convnet.predict(X_val)

# %%
ex = y_pred[20,:].copy()
ex = ex.reshape(46, 80)
plt.imshow(ex, cmap=plt.cm.gray)

# %%
plt.imshow(X_val[10].sum(axis=0), cmap=plt.cm.gray)
