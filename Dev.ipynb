# %%
from ModalDB import *
from schema import convcube_schema
client = ModalClient('./data/db', schema=convcube_schema)

# %% [markdown]
# ## Grab a video

# %%
video = client.get(Video, 'kitchen_1')

# %% [markdown]
# ## Grab a frame

# %%
frames = []
for frame in video.iter_children(childtype=Frame):
    frames.append(frame)

# %%
import matplotlib.pyplot as plt
# %pylab inline
plt.imshow(frames[100]['image'][:,:,::-1])
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Check how low we can downsample

# %%
from scipy.misc import imresize
from preprocess import imagenet_size
image = frames[50]['image'][:,:,::-1].copy()

image = imagenet_size(image)
print image.shape
plt.imshow(image)
# Out:
# (45, 80, 3)

# %% [markdown]
# ## Marking corners
# harris corners?

# %%
import cv2

def find_interesting_points(image):
    """finds interesting points to track"""
    feature_params = dict( maxCorners = 100,
                           qualityLevel = 0.3,
                           minDistance = 7,
                           blockSize = 7 )
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    p0 = cv2.goodFeaturesToTrack(gray, mask = None, **feature_params)
    return [tuple(p) for p in list(p0)]

# %%
image = frame['image'].copy()
points = find_interesting_points(image)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-84a07ec5695b> in <module>()
#       2 points = find_interesting_points(image)
#       3 for point in points:
# ----> 4     cv2.circle(image, point, 4, color=(255, 0, 0), thickness=3)
#
# TypeError: function takes exactly 2 arguments (1 given)
