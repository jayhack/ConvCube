# %%
# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

#=====[ Standard + Math ]=====
import os
import sys
sys.path.insert(0, './') #for faster development
import pickle
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %pylab inline

#=====[ ModalDB ]=====
from ModalDB import ModalClient
from ModalDB import Video
from ModalDB import Frame

#=====[ convcube ]=====
from convcube.schema import convcube_schema
from convcube.heatmapping import load_dataset_heatmap
from convcube.heatmapping import HeatmapConvNet
from convcube import ConvNetCube

#=====[ setup client ]=====
client = ModalClient('./data/db', schema=convcube_schema)
models_path = './models/localization'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Populating the interactive namespace from numpy and matplotlib

# %%
kpts = []
while len(kpts) == 0:
    frame = client.get_random(Frame)
    kpts = frame['interior_points']
    if kpts is None:
        kpts = []
plt.imshow(frame['image'][:,:,::-1])

# %%
from convcube.heatmapping.utils import get_X_heatmap, get_y_heatmap
img = get_X_heatmap(frame['image'], frame['interior_points'])
kpts, heatmap = get_y_heatmap(frame['image'], frame['interior_points'])
from scipy.misc import imresize
img = imresize(img, (45,80))
plt.imshow(img[:,:,::-1])

# %%
plt.imshow(heatmap, cmap=plt.cm.gray)
